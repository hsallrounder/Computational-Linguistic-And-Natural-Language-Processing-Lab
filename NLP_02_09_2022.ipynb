# %% [markdown]
# <a href="https://colab.research.google.com/github/hsallrounder/Computational-Linguistic-And-Natural-Language-Processing-Lab/blob/main/NLP_02_09_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
import os
import nltk.corpus
print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['conll2007.zip', 'swadesh.zip', 'mac_morpho.zip', 'names.zip', 'dolch.zip', 'sinica_treebank.zip', 'pl196x', 'comtrans.zip', 'smultron.zip', 'cess_cat', 'framenet_v15.zip', 'udhr.zip', 'europarl_raw.zip', 'masc_tagged.zip', 'semcor.zip', 'product_reviews_2', 'biocreative_ppi.zip', 'alpino.zip', 'mac_morpho', 'verbnet', 'genesis', 'cess_esp', 'opinion_lexicon.zip', 'senseval.zip', 'toolbox', 'switchboard.zip', 'words', 'twitter_samples', 'swadesh', 'machado.zip', 'framenet_v17.zip', 'webtext', 'qc', 'ppattach.zip', 'abc.zip', 'conll2000', 'sentiwordnet', 'nps_chat', 'ptb.zip', 'wordnet31.zip', 'inaugural', 'timit.zip', 'ycoe.zip', 'movie_reviews', 'stopwords', 'dolch', 'gazetteers.zip', 'lin_thesaurus', 'gutenberg.zip', 'reuters.zip', 'nonbreaking_prefixes.zip', 'senseval', 'wordnet_ic', 'shakespeare', 'sentence_polarity.zip', 'udhr2.zip', 'lin_thesaurus.zip', 'pe08', 'jeita.zip', 'switchboard', 'product_reviews_1', 'ycoe', 'europarl_raw', 'genesis.zip', 'framenet_v17', 'indian.zip',
# ...

# %%
from nltk.corpus import brown
print(brown.words())
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
c = 0
for i in brown.words():
    if c == 500:
        break
    c += 1
    print(i)
# Out:
# The
# Fulton
# County
# Grand
# Jury
# said
# Friday
# an
# investigation
# of
# Atlanta's
# recent
# primary
# election
# produced
# ``
# no
# evidence
# ''
# that
# any
# irregularities
# took
# place
# .
# The
# jury
# further
# said
# in
# term-end
# presentments
# that
# the
# City
# Executive
# Committee
# ,
# which
# had
# over-all
# charge
# of
# the
# election
# ,
# ``
# deserves
# the
# praise
# and
# thanks
# of
# the
# City
# of
# Atlanta
# ''
# for
# the
# manner
# in
# which
# the
# election
# was
# conducted
# .
# The
# September-October
# term
# jury
# had
# been
# charged
# by
# Fulton
# Superior
# Court
# Judge
# Durwood
# Pye
# to
# investigate
# reports
# of
# possible
# ``
# irregularities
# ''
# in
# the
# hard-fought
# primary
# which
# was
# won
# by
# Mayor-nominate
# Ivan
# Allen
# Jr.
# .
# ``
# Only
# a
# relative
# handful
# of
# such
# reports
# was
# received
# ''
# ,
# the
# jury
# said
# ,
# ``
# considering
# the
# widespread
# interest
# in
# the
# ...

# %%
from nltk.corpus import gutenberg
print(gutenberg.fileids())
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
import nltk.corpus
hamlet = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
print(hamlet)
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
for word in hamlet[:500]:
    print(word, sep=' ', end=' ')
# Out:
# [ The Tragedie of Hamlet by William Shakespeare 1599 ] Actus Primus . Scoena Prima . Enter Barnardo and Francisco two Centinels . Barnardo . Who ' s there ? Fran . Nay answer me : Stand & vnfold your selfe Bar . Long liue the King Fran . Barnardo ? Bar . He Fran . You come most carefully vpon your houre Bar . ' Tis now strook twelue , get thee to bed Francisco Fran . For this releefe much thankes : ' Tis bitter cold , And I am sicke at heart Barn . Haue you had quiet Guard ? Fran . Not a Mouse stirring Barn . Well , goodnight . If you do meet Horatio and Marcellus , the Riuals of my Watch , bid them make hast . Enter Horatio and Marcellus . Fran . I thinke I heare them . Stand : who ' s there ? Hor . Friends to this ground Mar . And Leige - men to the Dane Fran . Giue you good night Mar . O farwel honest Soldier , who hath relieu ' d you ? Fra . Barnardo ha ' s my place : giue you goodnight . Exit Fran . Mar . Holla Barnardo Bar . Say , what is Horatio there ? Hor . A peece of him Ba
# ...

# %%
dir(nltk)
# Out:
# ['ARLSTem',
#  'ARLSTem2',
#  'AbstractLazySequence',
#  'AffixTagger',
#  'AlignedSent',
#  'Alignment',
#  'AnnotationTask',
#  'ApplicationExpression',
#  'Assignment',
#  'BigramAssocMeasures',
#  'BigramCollocationFinder',
#  'BigramTagger',
#  'BinaryMaxentFeatureEncoding',
#  'BlanklineTokenizer',
#  'BllipParser',
#  'BottomUpChartParser',
#  'BottomUpLeftCornerChartParser',
#  'BottomUpProbabilisticChartParser',
#  'Boxer',
#  'BrillTagger',
#  'BrillTaggerTrainer',
#  'CFG',
#  'CRFTagger',
#  'CfgReadingCommand',
#  'ChartParser',
#  'ChunkParserI',
#  'ChunkScore',
#  'Cistem',
#  'ClassifierBasedPOSTagger',
#  'ClassifierBasedTagger',
#  'ClassifierI',
#  'ConcordanceIndex',
#  'ConditionalExponentialClassifier',
#  'ConditionalFreqDist',
#  'ConditionalProbDist',
#  'ConditionalProbDistI',
#  'ConfusionMatrix',
#  'ContextIndex',
#  'ContextTagger',
#  'ContingencyMeasures',
#  'CoreNLPDependencyParser',
#  'CoreNLPParser',
#  'Counter',
#  'CrossValidationProbDist',
# ...

# %%
from nltk.tokenize import word_tokenize
LI = '''Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.

Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.'''
print(type(LI))
LI_tokens = word_tokenize(LI)
print(LI_tokens)
# Out:
# <class 'str'>
# ...

# %%
from nltk.probability import FreqDist
fdist = FreqDist()
for word in LI_tokens:
    fdist[word.lower()] += 1
fdist
# Out:
# FreqDist({'the': 12, 'lorem': 8, 'ipsum': 8, 'of': 8, '.': 8, ',': 8, 'and': 6, 'it': 6, 'dummy': 4, 'text': 4, ...})

# %%
fdist['type']
# Out:
# 4

# %%
top10 = fdist.most_common(10)
top10
# Out:
# [('the', 12),
#  ('lorem', 8),
#  ('ipsum', 8),
#  ('of', 8),
#  ('.', 8),
#  (',', 8),
#  ('and', 6),
#  ('it', 6),
#  ('dummy', 4),
#  ('text', 4)]

# %%
from nltk.tokenize import blankline_tokenize
LI_blank = blankline_tokenize(LI)
len(LI_blank)
# Out:
# 2

# %%
p = LI_blank[0]
p
# Out:
# "Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."

# %%
from nltk.tokenize import sent_tokenize
LI_sent = sent_tokenize(LI)
len(LI_sent)
print(LI_sent)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry.', "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.", 'It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.', 'It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.', 'Lorem Ipsum is simply dummy text of the printing and typesetting industry.', "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.", 'It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.', 'It was popularised in the 1960s w
# ...

# %%
print(sent_tokenize("Dr. Sr Fr. Engineer "))
print(sent_tokenize("Dr. Sr. Fr Engineer "))
# Out:
# ['Dr. Sr Fr.', 'Engineer']
# ['Dr. Sr. Fr Engineer']

# %%
from nltk.util import bigrams, trigrams, ngrams
LI_bigrams=list(bigrams(LI_tokens))
LI_bigrams
# Out:
# [('Lorem', 'Ipsum'),
#  ('Ipsum', 'is'),
#  ('is', 'simply'),
#  ('simply', 'dummy'),
#  ('dummy', 'text'),
#  ('text', 'of'),
#  ('of', 'the'),
#  ('the', 'printing'),
#  ('printing', 'and'),
#  ('and', 'typesetting'),
#  ('typesetting', 'industry'),
#  ('industry', '.'),
#  ('.', 'Lorem'),
#  ('Lorem', 'Ipsum'),
#  ('Ipsum', 'has'),
#  ('has', 'been'),
#  ('been', 'the'),
#  ('the', 'industry'),
#  ('industry', "'s"),
#  ("'s", 'standard'),
#  ('standard', 'dummy'),
#  ('dummy', 'text'),
#  ('text', 'ever'),
#  ('ever', 'since'),
#  ('since', 'the'),
#  ('the', '1500s'),
#  ('1500s', ','),
#  (',', 'when'),
#  ('when', 'an'),
#  ('an', 'unknown'),
#  ('unknown', 'printer'),
#  ('printer', 'took'),
#  ('took', 'a'),
#  ('a', 'galley'),
#  ('galley', 'of'),
#  ('of', 'type'),
#  ('type', 'and'),
#  ('and', 'scrambled'),
#  ('scrambled', 'it'),
#  ('it', 'to'),
#  ('to', 'make'),
#  ('make', 'a'),
#  ('a', 'type'),
#  ('type', 'specimen'),
#  ('specimen', 'book'),
#  ('book', '.'),
# ...

# %%
LI_trigrams=list(trigrams(LI_tokens))
LI_trigrams
# Out:
# [('Lorem', 'Ipsum', 'is'),
#  ('Ipsum', 'is', 'simply'),
#  ('is', 'simply', 'dummy'),
#  ('simply', 'dummy', 'text'),
#  ('dummy', 'text', 'of'),
#  ('text', 'of', 'the'),
#  ('of', 'the', 'printing'),
#  ('the', 'printing', 'and'),
#  ('printing', 'and', 'typesetting'),
#  ('and', 'typesetting', 'industry'),
#  ('typesetting', 'industry', '.'),
#  ('industry', '.', 'Lorem'),
#  ('.', 'Lorem', 'Ipsum'),
#  ('Lorem', 'Ipsum', 'has'),
#  ('Ipsum', 'has', 'been'),
#  ('has', 'been', 'the'),
#  ('been', 'the', 'industry'),
#  ('the', 'industry', "'s"),
#  ('industry', "'s", 'standard'),
#  ("'s", 'standard', 'dummy'),
#  ('standard', 'dummy', 'text'),
#  ('dummy', 'text', 'ever'),
#  ('text', 'ever', 'since'),
#  ('ever', 'since', 'the'),
#  ('since', 'the', '1500s'),
#  ('the', '1500s', ','),
#  ('1500s', ',', 'when'),
#  (',', 'when', 'an'),
#  ('when', 'an', 'unknown'),
#  ('an', 'unknown', 'printer'),
#  ('unknown', 'printer', 'took'),
#  ('printer', 'took', 'a'),
# ...

# %%
n=4
LI_ngrams=list(ngrams(LI_tokens,n))
LI_ngrams
# Out:
# [('Lorem', 'Ipsum', 'is', 'simply'),
#  ('Ipsum', 'is', 'simply', 'dummy'),
#  ('is', 'simply', 'dummy', 'text'),
#  ('simply', 'dummy', 'text', 'of'),
#  ('dummy', 'text', 'of', 'the'),
#  ('text', 'of', 'the', 'printing'),
#  ('of', 'the', 'printing', 'and'),
#  ('the', 'printing', 'and', 'typesetting'),
#  ('printing', 'and', 'typesetting', 'industry'),
#  ('and', 'typesetting', 'industry', '.'),
#  ('typesetting', 'industry', '.', 'Lorem'),
#  ('industry', '.', 'Lorem', 'Ipsum'),
#  ('.', 'Lorem', 'Ipsum', 'has'),
#  ('Lorem', 'Ipsum', 'has', 'been'),
#  ('Ipsum', 'has', 'been', 'the'),
#  ('has', 'been', 'the', 'industry'),
#  ('been', 'the', 'industry', "'s"),
#  ('the', 'industry', "'s", 'standard'),
#  ('industry', "'s", 'standard', 'dummy'),
#  ("'s", 'standard', 'dummy', 'text'),
#  ('standard', 'dummy', 'text', 'ever'),
#  ('dummy', 'text', 'ever', 'since'),
#  ('text', 'ever', 'since', 'the'),
#  ('ever', 'since', 'the', '1500s'),
#  ('since', 'the', '1500s', ','),
# ...

# %%
#Character ngrams
n=8
LI_ngrams=list(ngrams("Yo! What's up?",n))
LI_ngrams
# Out:
# [('Y', 'o', '!', ' ', 'W', 'h', 'a', 't'),
#  ('o', '!', ' ', 'W', 'h', 'a', 't', "'"),
#  ('!', ' ', 'W', 'h', 'a', 't', "'", 's'),
#  (' ', 'W', 'h', 'a', 't', "'", 's', ' '),
#  ('W', 'h', 'a', 't', "'", 's', ' ', 'u'),
#  ('h', 'a', 't', "'", 's', ' ', 'u', 'p'),
#  ('a', 't', "'", 's', ' ', 'u', 'p', '?')]

# %% [markdown]
# **STOP WORDS**

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'whom', 'doing', 'were', "needn't", "couldn't", 'as', "that'll", 'during', 'myself', "mustn't", 'does', 'same', 're', 'in', 'yourself', 'once', 'until', 'being', 'am', 'we', 'while', 'd', 'has', 'ourselves', 'too', "should've", 'didn', "haven't", 'how', 'o', 'won', 'with', "doesn't", 'other', 'you', 'into', "hadn't", 'is', 'so', 'up', 'yours', 'itself', 'her', 'my', 'again', 'll', 'm', 'have', "you're", 'a', 'all', "didn't", 'before', "you'd", 'its', 'been', 'herself', 'those', 'only', 'further', 'mustn', 'him', 'he', 'by', 'them', 'and', "mightn't", 'it', 'this', 'weren', 'against', 'wasn', "aren't", 't', "hasn't", 'they', 'what', 'be', 'ain', 'there', 'mightn', "wasn't", 'some', 'why', 'just', 'who', 'themselves', 'theirs', 'our', 'doesn', 'each', 'for', 'do', 'between', 'me', 'their', 'the', 'aren', 've', 'below', 'was', 'hasn', 'very', 'isn', 'should', 'haven', "shan't", 'because', 'when', 'nor', "isn't", 'himself', 'about', 'most', 'own', "you've", 'after', 'couldn', 'not', 'sh
# ...

# %%
text="Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."
words=word_tokenize(text);
filtered_sentence=[]
for w in words:
  if w not in stop_words:
    filtered_sentence.append(w)
print(filtered_sentence)
# Out:
# ['Lorem', 'Ipsum', 'simply', 'dummy', 'text', 'printing', 'typesetting', 'industry', '.', 'Lorem', 'Ipsum', 'industry', "'s", 'standard', 'dummy', 'text', 'ever', 'since', '1500s', ',', 'unknown', 'printer', 'took', 'galley', 'type', 'scrambled', 'make', 'type', 'specimen', 'book', '.', 'It', 'survived', 'five', 'centuries', ',', 'also', 'leap', 'electronic', 'typesetting', ',', 'remaining', 'essentially', 'unchanged', '.', 'It', 'popularised', '1960s', 'release', 'Letraset', 'sheets', 'containing', 'Lorem', 'Ipsum', 'passages', ',', 'recently', 'desktop', 'publishing', 'software', 'like', 'Aldus', 'PageMaker', 'including', 'versions', 'Lorem', 'Ipsum', '.']

# %% [markdown]
# **STEMMING**

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
example_words=['python','pythoner','pythoning','pythoned','pythonly']
for w in example_words:
  print(ps.stem(w))
# Out:
# python
# python
# python
# python
# pythonli

# %%
from nltk.stem import LancasterStemmer
ls=LancasterStemmer()
example_words=['python','pythoner','pythoning','pythoned','pythonly']
for w in example_words:
  print(ls.stem(w))
# Out:
# python
# python
# python
# python
# python

# %%
from nltk.stem import SnowballStemmer
sbs=SnowballStemmer("english")
example_words=['python','pythoner','pythoning','pythoned','pythonly']
for w in example_words:
  print(sbs.stem(w))
# Out:
# python
# python
# python
# python
# python
